# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoFabian128/Calcular-cambio-if-else/blob/main/El_profe_Act_12_cambio_Hugo_Fabian_0040.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Hugo Fabian  NL = 15 Fecha 26/Mar/2026
# ### Clculando el cambio uando if else
# ### Mirara el diagrama de flujo
# <img src="https://raw.githubusercontent.com/HugoFabian128/Calcular-cambio-if-else/refs/heads/main/Cambio.jpg" width="400" height="200">
#
# ### las Variables
# 1. CP -->  Costo de producto
# 2. CD -->  Cantidad de dinero
# 3. Cambio
#
# ## Formulas
# $Cambio = CD - CP$
#
# ## Diagrama de flujo LucidChart
# <img src="https://raw.githubusercontent.com/HugoFabian128/Calcular-cambio-if-else/refs/heads/main/DF%20if%20else%20cambio.png" width="450" height="600">

# %%
# Para cuando es verdadero (si)
# Calcualando el cambio if else
# Datos de entrada CD, CP
# Mostrar cambio si es falso
# si es verdadero mostrar no alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP >= CD:
  print("No alcanza")
else:
  cambio = CD - CP
  print("El cambio es: ", cambio)
  print("Fin del programa")
  print("Programa realizado por Hugo NL = 15")
# Out:
# Ingrese el costo del producto: 100
# Ingrese la cantidad de dinero: 200
# El cambio es:  100.0
# Fin del programa
# Programa realizado por Hugo NL = 15

# %%
# Para cuando es falso (no)
# Calcualando el cambio if else
# Datos de entrada CD, CP
# Mostrar cambio si es falso
# si es falso moastrar no alzanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP >= CD:
  print("No alcanza")
else:
  cambio = CD - CP
  print("El cambio es: ", cambio)
print("Fin del programa")
print("Programa realizado por Hugo NL = 15")
# Out:
# Ingrese el costo del producto: 50
# Ingrese la cantidad de dinero: 20
# No alcanza
# Fin del programa
# Programa realizado por Hugo NL = 15

# %% [markdown]
# ## Relacion entre codigo y diagrama de flujo
# <img src="https://raw.githubusercontent.com/HugoFabian128/Calcular-cambio-if-else/refs/heads/main/TLDraw%20codigo%20DF.png" width="600" height="400">
